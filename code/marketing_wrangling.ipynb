# %%
import pandas as pd

# %%
df = pd.read_excel('marketing_data.xlsx')

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income  Dt_Customer  \
# 0      1826        1970  Graduation       Divorced  $84,835.00      6/16/14
# 1         1        1961  Graduation         Single  $57,091.00      6/15/14
# 2     10476        1958  Graduation        Married  $67,267.00      5/13/14
# 3      1386        1967  Graduation       Together  $32,474.00      5/11/14
# 4      5371        1989  Graduation         Single  $21,474.00       4/8/14
# ...     ...         ...         ...            ...          ...         ...
# 2235  10142        1976         PhD       Divorced  $66,476.00       3/7/13
# 2236   5263        1977    2n Cycle        Married  $31,056.00      1/22/13
# 2237     22        1976  Graduation       Divorced  $46,310.00      12/3/12
# 2238    528        1978  Graduation        Married  $65,819.00     11/29/12
# 2239   4070        1969         PhD        Married  $94,871.00       9/1/12
#
# ...

# %%
print(df.Marital_Status.unique())
# Out:
# ['Divorced' 'Single' 'Married' 'Together' 'Widow' 'YOLO' 'Alone' 'Absurd']

# %%
df['Marital_Status'] = df['Marital_Status'].replace(['YOLO', 'Alone', 'Absurd'],'Single')
df['Marital_Status'] = df['Marital_Status'].replace(['Together'],'In Relationship')

# %%
print(df.Marital_Status.unique())
# Out:
# ['Divorced' 'Single' 'Married' 'In Relationship' 'Widow']

# %%
df.drop('ID', axis = 1, inplace=True)

# %%
df
# Out:
#       Year_Birth   Education   Marital_Status      Income  Dt_Customer  \
# 0           1970  Graduation         Divorced  $84,835.00      6/16/14
# 1           1961  Graduation           Single  $57,091.00      6/15/14
# 2           1958  Graduation          Married  $67,267.00      5/13/14
# 3           1967  Graduation  In Relationship  $32,474.00      5/11/14
# 4           1989  Graduation           Single  $21,474.00       4/8/14
# ...          ...         ...              ...          ...         ...
# 2235        1976         PhD         Divorced  $66,476.00       3/7/13
# 2236        1977    2n Cycle          Married  $31,056.00      1/22/13
# 2237        1976  Graduation         Divorced  $46,310.00      12/3/12
# 2238        1978  Graduation          Married  $65,819.00     11/29/12
# 2239        1969         PhD          Married  $94,871.00       9/1/12
#
#       Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# ...

# %%
df['Age_Customers'] = 2014 - df['Year_Birth']

# %%
column_names = ['Year_Birth', 'Age_Customers', 'Education', 'Marital_Status',' Income ','Dt_Customer','Recency','MntWines', 'MntFruits',
        'MntMeatProducts', 'MntFishProducts', 'NumWebPurchases', 'NumWebVisitsMonth', 'AcceptedCmp1', 'AcceptedCmp2',
        'AcceptedCmp3','AcceptedCmp4','AcceptedCmp5']
df2 = df.reindex(columns=column_names)

# %%
df2
# Out:
#       Year_Birth  Age_Customers   Education   Marital_Status      Income   \
# 0           1970             44  Graduation         Divorced  $84,835.00
# 1           1961             53  Graduation           Single  $57,091.00
# 2           1958             56  Graduation          Married  $67,267.00
# 3           1967             47  Graduation  In Relationship  $32,474.00
# 4           1989             25  Graduation           Single  $21,474.00
# ...          ...            ...         ...              ...          ...
# 2235        1976             38         PhD         Divorced  $66,476.00
# 2236        1977             37    2n Cycle          Married  $31,056.00
# 2237        1976             38  Graduation         Divorced  $46,310.00
# 2238        1978             36  Graduation          Married  $65,819.00
# 2239        1969             45         PhD          Married  $94,871.00
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
df2.to_excel('marketing.xlsx')
